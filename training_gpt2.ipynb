# %%
# !pip install accelerate
# !pip install accelerate -U
# !pip install transformers[torch]
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.29.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
import glob

data_dir = 'datasets/babylm_10M/*.train'     # change if needed

# Use glob to get all .train files in the directory
file_paths = glob.glob(data_dir)

# Concatenate all text files into one big text file
with open("combined_dataset.txt", "w") as outfile:
    for file_path in file_paths:
        with open(file_path, "r") as infile:
            outfile.write(infile.read())

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer, Trainer, TrainingArguments, DataCollatorForLanguageModeling
from torch.utils.data import Dataset
import torch

# get text data from the concatenated text file
with open("combined_dataset.txt", "r") as file:
    text_data = file.read().splitlines()

# Initialize the tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# Set the padding token
tokenizer.pad_token = tokenizer.eos_token

# Tokenize the text data
inputs = tokenizer(text_data, return_tensors='pt', truncation=True, padding=True, max_length=512)

# Create a PyTorch dataset
class TextDataset(Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __getitem__(self, idx):
        return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}

    def __len__(self):
        return len(self.encodings.input_ids)

dataset = TextDataset(inputs)

# Initialize the model
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Resize the token embeddings
model.resize_token_embeddings(len(tokenizer))

# Initialize the data collator
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer, mlm=False
)

# Initialize the training arguments
training_args = TrainingArguments(
    output_dir='./results',          # output directory
    num_train_epochs=10,             # total number of training epochs
    per_device_train_batch_size=8,   # batch size per device during training
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir='./logs',            # directory for storing logs
    logging_steps=10,                # Log every X updates steps
    log_level='info',                # Set the logger to the 'info' level
    log_level_replica='info',        # Set the logger of the replicas to the 'info' level
    max_steps=100000,                # Limit the total number of training steps to 100000
)

# Initialize the trainer
trainer = Trainer(
    model=model,                         # the instantiated 🤗 Transformers model to be trained
    args=training_args,                  # training arguments, defined above
    train_dataset=dataset,               # training dataset
    data_collator=data_collator,
)

# Train the model
trainer.train()

# Save the model, tokenizer, and trainer state
model.save_pretrained('gpt2_dir/')
tokenizer.save_pretrained('gpt2_dir/')
# Out:
# loading file vocab.json from cache at /root/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/vocab.json
# loading file merges.txt from cache at /root/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/merges.txt
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/tokenizer_config.json
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/tokenizer.json
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "_name_or_path": "gpt2",
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.38.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.38.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/model.safetensors
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256
# }
#
# All model checkpoint weights were used when initializing GPT2LMHeadModel.
#
# All the weights of GPT2LMHeadModel were initialized from the model checkpoint at gpt2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use GPT2LMHeadModel for predictions without further training.
# loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/generation_config.json
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256
# }
#
# You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embedding dimension will be 50257. This might induce some performance reduction as *Tensor Cores* will not be available. For more details about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:436: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
# max_steps is given, it will override any value given in num_train_epochs
# ***** Running training *****
#   Num examples = 1,058,749
#   Num Epochs = 1
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 100,000
#   Number of trainable parameters = 124,439,808
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
#     <div>
#
#       <progress value='62001' max='100000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 62001/100000 4:55:40 < 3:01:13, 3.49 it/s, Epoch 0.47/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>4.742100</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>4.618300</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>4.815500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>4.889900</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>4.784700</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>4.684200</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>4.616400</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>4.436000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>4.596500</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>4.518900</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>4.542900</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>4.299300</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>4.274400</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>4.250400</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>4.531700</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>4.519100</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>4.357800</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>4.418900</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>4.155000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>4.302300</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>4.621000</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>4.238200</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>4.614300</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>4.519100</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>4.337200</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>4.317200</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>4.405500</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>4.426100</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>4.221900</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>4.295600</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>4.300100</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>4.440600</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>4.661100</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>4.215400</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>4.309700</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>4.471800</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>4.526700</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>4.173000</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>4.322100</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>4.464100</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>4.276800</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>4.482600</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>4.320800</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>4.446100</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>4.328000</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>4.159800</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>4.347300</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>4.420200</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>4.142800</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>4.488600</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>4.365900</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>4.353800</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>4.045600</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>4.308800</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>4.232100</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>4.232300</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>4.381500</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>4.204600</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>4.117100</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>4.077300</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>4.258000</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>4.246100</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>4.101800</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>4.317500</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>4.317700</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>4.279600</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>4.157800</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>4.266100</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>4.207800</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>4.115700</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>4.286600</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>4.159000</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>4.141800</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>4.294100</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>4.237500</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>4.284300</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>4.319200</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>4.008900</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>4.193000</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>4.243100</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>4.477700</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>4.419600</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>4.192100</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>4.295400</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>4.328700</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>4.184800</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>4.033500</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>4.200100</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>4.260100</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>4.125900</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>4.235400</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>4.187300</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>4.312000</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>4.386500</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>4.429000</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>4.345900</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>4.127200</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>4.164800</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>4.382600</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>3.911300</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>4.241100</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>4.292900</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>4.197000</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>4.057500</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>4.147700</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>4.130100</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>4.119600</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>4.460900</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>4.229500</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>4.204700</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>3.953900</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>4.247200</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>4.015000</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>4.257400</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>4.188600</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>4.020500</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>4.156800</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>4.221900</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>3.989200</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>4.145900</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>3.888700</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>4.087800</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>4.157600</td>
# Saving model checkpoint to ./results/tmp-checkpoint-500
# Configuration saved in ./results/tmp-checkpoint-500/config.json
# Configuration saved in ./results/tmp-checkpoint-500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-1000
# Configuration saved in ./results/tmp-checkpoint-1000/config.json
# Configuration saved in ./results/tmp-checkpoint-1000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-1000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-1500
# Configuration saved in ./results/tmp-checkpoint-1500/config.json
# Configuration saved in ./results/tmp-checkpoint-1500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-1500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-2000
# Configuration saved in ./results/tmp-checkpoint-2000/config.json
# Configuration saved in ./results/tmp-checkpoint-2000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-2000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-2500
# Configuration saved in ./results/tmp-checkpoint-2500/config.json
# Configuration saved in ./results/tmp-checkpoint-2500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-2500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-3000
# Configuration saved in ./results/tmp-checkpoint-3000/config.json
# Configuration saved in ./results/tmp-checkpoint-3000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-3000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-3500
# Configuration saved in ./results/tmp-checkpoint-3500/config.json
# Configuration saved in ./results/tmp-checkpoint-3500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-3500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-4000
# Configuration saved in ./results/tmp-checkpoint-4000/config.json
# Configuration saved in ./results/tmp-checkpoint-4000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-4000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-4500
# Configuration saved in ./results/tmp-checkpoint-4500/config.json
# Configuration saved in ./results/tmp-checkpoint-4500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-4500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-5000
# Configuration saved in ./results/tmp-checkpoint-5000/config.json
# Configuration saved in ./results/tmp-checkpoint-5000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-5000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-5500
# Configuration saved in ./results/tmp-checkpoint-5500/config.json
# Configuration saved in ./results/tmp-checkpoint-5500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-5500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-6000
# Configuration saved in ./results/tmp-checkpoint-6000/config.json
# Configuration saved in ./results/tmp-checkpoint-6000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-6000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-6500
# Configuration saved in ./results/tmp-checkpoint-6500/config.json
# Configuration saved in ./results/tmp-checkpoint-6500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-6500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-7000
# Configuration saved in ./results/tmp-checkpoint-7000/config.json
# Configuration saved in ./results/tmp-checkpoint-7000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-7000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-7500
# Configuration saved in ./results/tmp-checkpoint-7500/config.json
# Configuration saved in ./results/tmp-checkpoint-7500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-7500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-8000
# Configuration saved in ./results/tmp-checkpoint-8000/config.json
# Configuration saved in ./results/tmp-checkpoint-8000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-8000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-8500
# Configuration saved in ./results/tmp-checkpoint-8500/config.json
# Configuration saved in ./results/tmp-checkpoint-8500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-8500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-9000
# Configuration saved in ./results/tmp-checkpoint-9000/config.json
# Configuration saved in ./results/tmp-checkpoint-9000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-9000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-9500
# Configuration saved in ./results/tmp-checkpoint-9500/config.json
# Configuration saved in ./results/tmp-checkpoint-9500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-9500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-10000
# Configuration saved in ./results/tmp-checkpoint-10000/config.json
# Configuration saved in ./results/tmp-checkpoint-10000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-10000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-10500
# Configuration saved in ./results/tmp-checkpoint-10500/config.json
# Configuration saved in ./results/tmp-checkpoint-10500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-10500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-11000
# Configuration saved in ./results/tmp-checkpoint-11000/config.json
# Configuration saved in ./results/tmp-checkpoint-11000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-11000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-11500
# Configuration saved in ./results/tmp-checkpoint-11500/config.json
# Configuration saved in ./results/tmp-checkpoint-11500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-11500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-12000
# Configuration saved in ./results/tmp-checkpoint-12000/config.json
# Configuration saved in ./results/tmp-checkpoint-12000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-12000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-12500
# Configuration saved in ./results/tmp-checkpoint-12500/config.json
# Configuration saved in ./results/tmp-checkpoint-12500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-12500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-13000
# Configuration saved in ./results/tmp-checkpoint-13000/config.json
# Configuration saved in ./results/tmp-checkpoint-13000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-13000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-13500
# Configuration saved in ./results/tmp-checkpoint-13500/config.json
# Configuration saved in ./results/tmp-checkpoint-13500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-13500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-14000
# Configuration saved in ./results/tmp-checkpoint-14000/config.json
# Configuration saved in ./results/tmp-checkpoint-14000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-14000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-14500
# Configuration saved in ./results/tmp-checkpoint-14500/config.json
# Configuration saved in ./results/tmp-checkpoint-14500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-14500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-15000
# Configuration saved in ./results/tmp-checkpoint-15000/config.json
# Configuration saved in ./results/tmp-checkpoint-15000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-15000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-15500
# Configuration saved in ./results/tmp-checkpoint-15500/config.json
# Configuration saved in ./results/tmp-checkpoint-15500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-15500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-16000
# Configuration saved in ./results/tmp-checkpoint-16000/config.json
# Configuration saved in ./results/tmp-checkpoint-16000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-16000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-16500
# Configuration saved in ./results/tmp-checkpoint-16500/config.json
# Configuration saved in ./results/tmp-checkpoint-16500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-16500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-17000
# Configuration saved in ./results/tmp-checkpoint-17000/config.json
# Configuration saved in ./results/tmp-checkpoint-17000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-17000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-17500
# Configuration saved in ./results/tmp-checkpoint-17500/config.json
# Configuration saved in ./results/tmp-checkpoint-17500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-17500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-18000
# Configuration saved in ./results/tmp-checkpoint-18000/config.json
# Configuration saved in ./results/tmp-checkpoint-18000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-18000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-18500
# Configuration saved in ./results/tmp-checkpoint-18500/config.json
# Configuration saved in ./results/tmp-checkpoint-18500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-18500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-19000
# Configuration saved in ./results/tmp-checkpoint-19000/config.json
# Configuration saved in ./results/tmp-checkpoint-19000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-19000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-19500
# Configuration saved in ./results/tmp-checkpoint-19500/config.json
# Configuration saved in ./results/tmp-checkpoint-19500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-19500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-20000
# Configuration saved in ./results/tmp-checkpoint-20000/config.json
# Configuration saved in ./results/tmp-checkpoint-20000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-20000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-20500
# Configuration saved in ./results/tmp-checkpoint-20500/config.json
# Configuration saved in ./results/tmp-checkpoint-20500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-20500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-21000
# Configuration saved in ./results/tmp-checkpoint-21000/config.json
# Configuration saved in ./results/tmp-checkpoint-21000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-21000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-21500
# Configuration saved in ./results/tmp-checkpoint-21500/config.json
# Configuration saved in ./results/tmp-checkpoint-21500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-21500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-22000
# Configuration saved in ./results/tmp-checkpoint-22000/config.json
# Configuration saved in ./results/tmp-checkpoint-22000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-22000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-22500
# Configuration saved in ./results/tmp-checkpoint-22500/config.json
# Configuration saved in ./results/tmp-checkpoint-22500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-22500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-23000
# Configuration saved in ./results/tmp-checkpoint-23000/config.json
# Configuration saved in ./results/tmp-checkpoint-23000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-23000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-23500
# Configuration saved in ./results/tmp-checkpoint-23500/config.json
# Configuration saved in ./results/tmp-checkpoint-23500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-23500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-24000
# Configuration saved in ./results/tmp-checkpoint-24000/config.json
# Configuration saved in ./results/tmp-checkpoint-24000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-24000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-24500
# Configuration saved in ./results/tmp-checkpoint-24500/config.json
# Configuration saved in ./results/tmp-checkpoint-24500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-24500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-25000
# Configuration saved in ./results/tmp-checkpoint-25000/config.json
# Configuration saved in ./results/tmp-checkpoint-25000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-25000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-25500
# Configuration saved in ./results/tmp-checkpoint-25500/config.json
# Configuration saved in ./results/tmp-checkpoint-25500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-25500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-26000
# Configuration saved in ./results/tmp-checkpoint-26000/config.json
# Configuration saved in ./results/tmp-checkpoint-26000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-26000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-26500
# Configuration saved in ./results/tmp-checkpoint-26500/config.json
# Configuration saved in ./results/tmp-checkpoint-26500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-26500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-27000
# Configuration saved in ./results/tmp-checkpoint-27000/config.json
# Configuration saved in ./results/tmp-checkpoint-27000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-27000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-27500
# Configuration saved in ./results/tmp-checkpoint-27500/config.json
# Configuration saved in ./results/tmp-checkpoint-27500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-27500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-28000
# Configuration saved in ./results/tmp-checkpoint-28000/config.json
# Configuration saved in ./results/tmp-checkpoint-28000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-28000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-28500
# Configuration saved in ./results/tmp-checkpoint-28500/config.json
# Configuration saved in ./results/tmp-checkpoint-28500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-28500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-29000
# Configuration saved in ./results/tmp-checkpoint-29000/config.json
# Configuration saved in ./results/tmp-checkpoint-29000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-29000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-29500
# Configuration saved in ./results/tmp-checkpoint-29500/config.json
# Configuration saved in ./results/tmp-checkpoint-29500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-29500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-30000
# Configuration saved in ./results/tmp-checkpoint-30000/config.json
# ...
# Model weights saved in ./results/tmp-checkpoint-51500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-52000
# Configuration saved in ./results/tmp-checkpoint-52000/config.json
# Configuration saved in ./results/tmp-checkpoint-52000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-52000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-52500
# Configuration saved in ./results/tmp-checkpoint-52500/config.json
# Configuration saved in ./results/tmp-checkpoint-52500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-52500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-53000
# Configuration saved in ./results/tmp-checkpoint-53000/config.json
# Configuration saved in ./results/tmp-checkpoint-53000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-53000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-53500
# Configuration saved in ./results/tmp-checkpoint-53500/config.json
# Configuration saved in ./results/tmp-checkpoint-53500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-53500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-54000
# Configuration saved in ./results/tmp-checkpoint-54000/config.json
# Configuration saved in ./results/tmp-checkpoint-54000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-54000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-54500
# Configuration saved in ./results/tmp-checkpoint-54500/config.json
# Configuration saved in ./results/tmp-checkpoint-54500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-54500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-55000
# Configuration saved in ./results/tmp-checkpoint-55000/config.json
# Configuration saved in ./results/tmp-checkpoint-55000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-55000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-55500
# Configuration saved in ./results/tmp-checkpoint-55500/config.json
# Configuration saved in ./results/tmp-checkpoint-55500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-55500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-56000
# Configuration saved in ./results/tmp-checkpoint-56000/config.json
# Configuration saved in ./results/tmp-checkpoint-56000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-56000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-56500
# Configuration saved in ./results/tmp-checkpoint-56500/config.json
# Configuration saved in ./results/tmp-checkpoint-56500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-56500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-57000
# Configuration saved in ./results/tmp-checkpoint-57000/config.json
# Configuration saved in ./results/tmp-checkpoint-57000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-57000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-57500
# Configuration saved in ./results/tmp-checkpoint-57500/config.json
# Configuration saved in ./results/tmp-checkpoint-57500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-57500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-58000
# Configuration saved in ./results/tmp-checkpoint-58000/config.json
# Configuration saved in ./results/tmp-checkpoint-58000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-58000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-58500
# Configuration saved in ./results/tmp-checkpoint-58500/config.json
# Configuration saved in ./results/tmp-checkpoint-58500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-58500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-59000
# Configuration saved in ./results/tmp-checkpoint-59000/config.json
# Configuration saved in ./results/tmp-checkpoint-59000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-59000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-59500
# Configuration saved in ./results/tmp-checkpoint-59500/config.json
# Configuration saved in ./results/tmp-checkpoint-59500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-59500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-60000
# Configuration saved in ./results/tmp-checkpoint-60000/config.json
# Configuration saved in ./results/tmp-checkpoint-60000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-60000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-60500
# Configuration saved in ./results/tmp-checkpoint-60500/config.json
# Configuration saved in ./results/tmp-checkpoint-60500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-60500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-61000
# Configuration saved in ./results/tmp-checkpoint-61000/config.json
# Configuration saved in ./results/tmp-checkpoint-61000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-61000/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-61500
# Configuration saved in ./results/tmp-checkpoint-61500/config.json
# Configuration saved in ./results/tmp-checkpoint-61500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-61500/model.safetensors
# <ipython-input-6-c354d716304e>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-62000
# Configuration saved in ./results/tmp-checkpoint-62000/config.json
# Configuration saved in ./results/tmp-checkpoint-62000/generation_config.json
# ---------------------------------------------------------------------------
# SafetensorError                           Traceback (most recent call last)
# <ipython-input-6-c354d716304e> in <cell line: 73>()
#      71
#      72 # Train the model
# ---> 73 trainer.train()
#      74
#      75 # Save the model, tokenizer, and trainer state
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1622                 hf_hub_utils.enable_progress_bars()
#    1623         else:
# -> 1624             return inner_training_loop(
#    1625                 args=args,
#    1626                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2027                     self.control = self.callback_handler.on_step_end(args, self.state, self.control)
#    2028
# -> 2029                     self._maybe_log_save_evaluate(tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval)
#    2030                 else:
#    2031                     self.control = self.callback_handler.on_substep_end(args, self.state, self.control)
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval)
#    2421
#    2422         if self.control.should_save:
# -> 2423             self._save_checkpoint(model, trial, metrics=metrics)
#    2424             self.control = self.callback_handler.on_save(self.args, self.state, self.control)
#    2425
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _save_checkpoint(self, model, trial, metrics)
#    2497         else:
#    2498             staging_output_dir = os.path.join(run_dir, f"tmp-{checkpoint_folder}")
# -> 2499         self.save_model(staging_output_dir, _internal_call=True)
#    2500
#    2501         if not self.args.save_only_model:
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in save_model(self, output_dir, _internal_call)
#    3014
#    3015         elif self.args.should_save:
# -> 3016             self._save(output_dir)
#    3017
#    3018         # Push to the Hub when `save_model` is called by the user.
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _save(self, output_dir, state_dict)
#    3087                     torch.save(state_dict, os.path.join(output_dir, WEIGHTS_NAME))
#    3088         else:
# -> 3089             self.model.save_pretrained(
#    3090                 output_dir, state_dict=state_dict, safe_serialization=self.args.save_safetensors
#    3091             )
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in save_pretrained(self, save_directory, is_main_process, state_dict, save_function, push_to_hub, max_shard_size, safe_serialization, variant, token, save_peft_format, **kwargs)
#    2446                 # At some point we will need to deal better with save_function (used for TPU and other distributed
#    2447                 # joyfulness), but for now this enough.
# -> 2448                 safe_save_file(shard, os.path.join(save_directory, shard_file), metadata={"format": "pt"})
#    2449             else:
#    2450                 save_function(shard, os.path.join(save_directory, shard_file))
#
# /usr/local/lib/python3.10/dist-packages/safetensors/torch.py in save_file(tensors, filename, metadata)
#     282     ```
#     283     """
# --> 284     serialize_file(_flatten(tensors), filename, metadata=metadata)
#     285
#     286
#
# SafetensorError: Error while serializing: IoError(Os { code: 28, kind: StorageFull, message: "No space left on device" })

# %%
# %%shell
# cd results
# find . -type d -name 'checkpoint-*' ! -name 'checkpoint-61500' -exec rm -r {} +

# %%
# # Initialize the model from a checkpoint
# model = GPT2LMHeadModel.from_pretrained('results/checkpoint-61500')

# # Initialize the tokenizer
# tokenizer = GPT2Tokenizer.from_pretrained('results/checkpoint-61500')

# Set the padding token
tokenizer.pad_token = tokenizer.eos_token

# Tokenize the text data
inputs = tokenizer(text_data, return_tensors='pt', truncation=True, padding=True, max_length=512)

# Create a PyTorch dataset
class TextDataset(Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __getitem__(self, idx):
        return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}

    def __len__(self):
        return len(self.encodings.input_ids)

dataset = TextDataset(inputs)

# Resize the token embeddings
model.resize_token_embeddings(len(tokenizer))

# Initialize the data collator
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer, mlm=False
)

# Initialize the training arguments
training_args = TrainingArguments(
    output_dir='./results',          # output directory
    num_train_epochs=10,             # total number of training epochs
    per_device_train_batch_size=8,   # batch size per device during training
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir='./logs',            # directory for storing logs
    logging_steps=10,                # Log every X updates steps
    log_level='info',                # Set the logger to the 'info' level
    log_level_replica='info',        # Set the logger of the replicas to the 'info' level
    max_steps=100000,                # Limit the total number of training steps to 100000
    save_steps=1000,                 # Save a checkpoint every 1000 steps
)

# Initialize the trainer
trainer = Trainer(
    model=model,                         # the instantiated 🤗 Transformers model to be trained
    args=training_args,                  # training arguments, defined above
    train_dataset=dataset,               # training dataset
    data_collator=data_collator,
)

# Train the model from a checkpoint
trainer.train('results/checkpoint-61500')

# Save the model, tokenizer, and trainer state
model.save_pretrained('model_dir/')
tokenizer.save_pretrained('model_dir/')
# Out:
# You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embedding dimension will be 50257. This might induce some performance reduction as *Tensor Cores* will not be available. For more details about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:436: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
# max_steps is given, it will override any value given in num_train_epochs
# Loading model from results/checkpoint-61500.
# There were missing keys in the checkpoint model loaded: ['lm_head.weight'].
# ***** Running training *****
#   Num examples = 1,058,749
#   Num Epochs = 1
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 100,000
#   Number of trainable parameters = 124,439,808
#   Continuing training from checkpoint, will skip to saved global_step
#   Continuing training from epoch 0
#   Continuing training from global step 61500
#   Will skip the first 0 epochs then the first 61500 batches in the first epoch.
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
#     <div>
#
#       <progress value='100000' max='100000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100000/100000 3:02:34, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>61510</td>
#       <td>4.156800</td>
#     </tr>
#     <tr>
#       <td>61520</td>
#       <td>3.930200</td>
#     </tr>
#     <tr>
#       <td>61530</td>
#       <td>4.007400</td>
#     </tr>
#     <tr>
#       <td>61540</td>
#       <td>3.871500</td>
#     </tr>
#     <tr>
#       <td>61550</td>
#       <td>3.908300</td>
#     </tr>
#     <tr>
#       <td>61560</td>
#       <td>4.088900</td>
#     </tr>
#     <tr>
#       <td>61570</td>
#       <td>4.055200</td>
#     </tr>
#     <tr>
#       <td>61580</td>
#       <td>3.755600</td>
#     </tr>
#     <tr>
#       <td>61590</td>
#       <td>4.100500</td>
#     </tr>
#     <tr>
#       <td>61600</td>
#       <td>3.677200</td>
#     </tr>
#     <tr>
#       <td>61610</td>
#       <td>3.873100</td>
#     </tr>
#     <tr>
#       <td>61620</td>
#       <td>4.160800</td>
#     </tr>
#     <tr>
#       <td>61630</td>
#       <td>4.180600</td>
#     </tr>
#     <tr>
#       <td>61640</td>
#       <td>3.996900</td>
#     </tr>
#     <tr>
#       <td>61650</td>
#       <td>3.895400</td>
#     </tr>
#     <tr>
#       <td>61660</td>
#       <td>3.847800</td>
#     </tr>
#     <tr>
#       <td>61670</td>
#       <td>3.941600</td>
#     </tr>
#     <tr>
#       <td>61680</td>
#       <td>3.875500</td>
#     </tr>
#     <tr>
#       <td>61690</td>
#       <td>4.106600</td>
#     </tr>
#     <tr>
#       <td>61700</td>
#       <td>3.707300</td>
#     </tr>
#     <tr>
#       <td>61710</td>
#       <td>3.855400</td>
#     </tr>
#     <tr>
#       <td>61720</td>
#       <td>3.883200</td>
#     </tr>
#     <tr>
#       <td>61730</td>
#       <td>3.872000</td>
#     </tr>
#     <tr>
#       <td>61740</td>
#       <td>3.828200</td>
#     </tr>
#     <tr>
#       <td>61750</td>
#       <td>3.875700</td>
#     </tr>
#     <tr>
#       <td>61760</td>
#       <td>3.981600</td>
#     </tr>
#     <tr>
#       <td>61770</td>
#       <td>3.918000</td>
#     </tr>
#     <tr>
#       <td>61780</td>
#       <td>3.882600</td>
#     </tr>
#     <tr>
#       <td>61790</td>
#       <td>4.009100</td>
#     </tr>
#     <tr>
#       <td>61800</td>
#       <td>3.942400</td>
#     </tr>
#     <tr>
#       <td>61810</td>
#       <td>3.889500</td>
#     </tr>
#     <tr>
#       <td>61820</td>
#       <td>3.919700</td>
#     </tr>
#     <tr>
#       <td>61830</td>
#       <td>3.873000</td>
#     </tr>
#     <tr>
#       <td>61840</td>
#       <td>3.908000</td>
#     </tr>
#     <tr>
#       <td>61850</td>
#       <td>4.018500</td>
#     </tr>
#     <tr>
#       <td>61860</td>
#       <td>3.807300</td>
#     </tr>
#     <tr>
#       <td>61870</td>
#       <td>3.706100</td>
#     </tr>
#     <tr>
#       <td>61880</td>
#       <td>3.627700</td>
#     </tr>
#     <tr>
#       <td>61890</td>
#       <td>3.790900</td>
#     </tr>
#     <tr>
#       <td>61900</td>
#       <td>3.883900</td>
#     </tr>
#     <tr>
#       <td>61910</td>
#       <td>3.761300</td>
#     </tr>
#     <tr>
#       <td>61920</td>
#       <td>4.114000</td>
#     </tr>
#     <tr>
#       <td>61930</td>
#       <td>3.882900</td>
#     </tr>
#     <tr>
#       <td>61940</td>
#       <td>3.803900</td>
#     </tr>
#     <tr>
#       <td>61950</td>
#       <td>3.897400</td>
#     </tr>
#     <tr>
#       <td>61960</td>
#       <td>3.804400</td>
#     </tr>
#     <tr>
#       <td>61970</td>
#       <td>3.857700</td>
#     </tr>
#     <tr>
#       <td>61980</td>
#       <td>3.780400</td>
#     </tr>
#     <tr>
#       <td>61990</td>
#       <td>3.914200</td>
#     </tr>
#     <tr>
#       <td>62000</td>
#       <td>3.851600</td>
#     </tr>
#     <tr>
#       <td>62010</td>
#       <td>4.041000</td>
#     </tr>
#     <tr>
#       <td>62020</td>
#       <td>3.832000</td>
#     </tr>
#     <tr>
#       <td>62030</td>
#       <td>4.105700</td>
#     </tr>
#     <tr>
#       <td>62040</td>
#       <td>4.031500</td>
#     </tr>
#     <tr>
#       <td>62050</td>
#       <td>3.851900</td>
#     </tr>
#     <tr>
#       <td>62060</td>
#       <td>4.021800</td>
#     </tr>
#     <tr>
#       <td>62070</td>
#       <td>3.921200</td>
#     </tr>
#     <tr>
#       <td>62080</td>
#       <td>4.018200</td>
#     </tr>
#     <tr>
#       <td>62090</td>
#       <td>3.904100</td>
#     </tr>
#     <tr>
#       <td>62100</td>
#       <td>4.029400</td>
#     </tr>
#     <tr>
#       <td>62110</td>
#       <td>4.018700</td>
#     </tr>
#     <tr>
#       <td>62120</td>
#       <td>3.853400</td>
#     </tr>
#     <tr>
#       <td>62130</td>
#       <td>3.757800</td>
#     </tr>
#     <tr>
#       <td>62140</td>
#       <td>3.868900</td>
#     </tr>
#     <tr>
#       <td>62150</td>
#       <td>3.843200</td>
#     </tr>
#     <tr>
#       <td>62160</td>
#       <td>3.923000</td>
#     </tr>
#     <tr>
#       <td>62170</td>
#       <td>3.885300</td>
#     </tr>
#     <tr>
#       <td>62180</td>
#       <td>3.957400</td>
#     </tr>
#     <tr>
#       <td>62190</td>
#       <td>4.038900</td>
#     </tr>
#     <tr>
#       <td>62200</td>
#       <td>3.841000</td>
#     </tr>
#     <tr>
#       <td>62210</td>
#       <td>3.926600</td>
#     </tr>
#     <tr>
#       <td>62220</td>
#       <td>4.106800</td>
#     </tr>
#     <tr>
#       <td>62230</td>
#       <td>4.138200</td>
#     </tr>
#     <tr>
#       <td>62240</td>
#       <td>3.806900</td>
#     </tr>
#     <tr>
#       <td>62250</td>
#       <td>4.002300</td>
#     </tr>
#     <tr>
#       <td>62260</td>
#       <td>3.886300</td>
#     </tr>
#     <tr>
#       <td>62270</td>
#       <td>3.906000</td>
#     </tr>
#     <tr>
#       <td>62280</td>
#       <td>3.930400</td>
#     </tr>
#     <tr>
#       <td>62290</td>
#       <td>3.745200</td>
#     </tr>
#     <tr>
#       <td>62300</td>
#       <td>4.047800</td>
#     </tr>
#     <tr>
#       <td>62310</td>
#       <td>3.688400</td>
#     </tr>
#     <tr>
#       <td>62320</td>
#       <td>3.739600</td>
#     </tr>
#     <tr>
#       <td>62330</td>
#       <td>4.046100</td>
#     </tr>
#     <tr>
#       <td>62340</td>
#       <td>3.714600</td>
#     </tr>
#     <tr>
#       <td>62350</td>
#       <td>3.930900</td>
#     </tr>
#     <tr>
#       <td>62360</td>
#       <td>3.656300</td>
#     </tr>
#     <tr>
#       <td>62370</td>
#       <td>4.127400</td>
#     </tr>
#     <tr>
#       <td>62380</td>
#       <td>3.619500</td>
#     </tr>
#     <tr>
#       <td>62390</td>
#       <td>3.544900</td>
#     </tr>
#     <tr>
#       <td>62400</td>
#       <td>3.585400</td>
#     </tr>
#     <tr>
#       <td>62410</td>
#       <td>3.891500</td>
#     </tr>
#     <tr>
#       <td>62420</td>
#       <td>3.809600</td>
#     </tr>
#     <tr>
#       <td>62430</td>
#       <td>4.001100</td>
#     </tr>
#     <tr>
#       <td>62440</td>
#       <td>3.815800</td>
#     </tr>
#     <tr>
#       <td>62450</td>
#       <td>4.083400</td>
#     </tr>
#     <tr>
#       <td>62460</td>
#       <td>3.659600</td>
#     </tr>
#     <tr>
#       <td>62470</td>
#       <td>4.025400</td>
#     </tr>
#     <tr>
#       <td>62480</td>
#       <td>3.897900</td>
#     </tr>
#     <tr>
#       <td>62490</td>
#       <td>3.973600</td>
#     </tr>
#     <tr>
#       <td>62500</td>
#       <td>3.685500</td>
#     </tr>
#     <tr>
#       <td>62510</td>
#       <td>3.682300</td>
#     </tr>
#     <tr>
#       <td>62520</td>
#       <td>3.735600</td>
#     </tr>
#     <tr>
#       <td>62530</td>
#       <td>4.064900</td>
#     </tr>
#     <tr>
#       <td>62540</td>
#       <td>3.662900</td>
#     </tr>
#     <tr>
#       <td>62550</td>
#       <td>3.847000</td>
#     </tr>
#     <tr>
#       <td>62560</td>
#       <td>3.876800</td>
#     </tr>
#     <tr>
#       <td>62570</td>
#       <td>3.631100</td>
#     </tr>
#     <tr>
#       <td>62580</td>
#       <td>3.761500</td>
#     </tr>
#     <tr>
#       <td>62590</td>
#       <td>3.918800</td>
#     </tr>
#     <tr>
#       <td>62600</td>
#       <td>3.763700</td>
#     </tr>
#     <tr>
#       <td>62610</td>
#       <td>3.835500</td>
#     </tr>
#     <tr>
#       <td>62620</td>
#       <td>3.918600</td>
#     </tr>
#     <tr>
#       <td>62630</td>
#       <td>3.922700</td>
#     </tr>
#     <tr>
#       <td>62640</td>
#       <td>3.824200</td>
#     </tr>
#     <tr>
#       <td>62650</td>
#       <td>3.875100</td>
#     </tr>
#     <tr>
#       <td>62660</td>
#       <td>3.922200</td>
#     </tr>
#     <tr>
#       <td>62670</td>
#       <td>3.967200</td>
#     </tr>
#     <tr>
#       <td>62680</td>
#       <td>3.892600</td>
#     </tr>
#     <tr>
#       <td>62690</td>
#       <td>4.210300</td>
#     </tr>
#     <tr>
#       <td>62700</td>
#       <
# Saving model checkpoint to ./results/tmp-checkpoint-62000
# Configuration saved in ./results/tmp-checkpoint-62000/config.json
# Configuration saved in ./results/tmp-checkpoint-62000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-62000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-62500
# Configuration saved in ./results/tmp-checkpoint-62500/config.json
# Configuration saved in ./results/tmp-checkpoint-62500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-62500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-63000
# Configuration saved in ./results/tmp-checkpoint-63000/config.json
# Configuration saved in ./results/tmp-checkpoint-63000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-63000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-63500
# Configuration saved in ./results/tmp-checkpoint-63500/config.json
# Configuration saved in ./results/tmp-checkpoint-63500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-63500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-64000
# Configuration saved in ./results/tmp-checkpoint-64000/config.json
# Configuration saved in ./results/tmp-checkpoint-64000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-64000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-64500
# Configuration saved in ./results/tmp-checkpoint-64500/config.json
# Configuration saved in ./results/tmp-checkpoint-64500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-64500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-65000
# Configuration saved in ./results/tmp-checkpoint-65000/config.json
# Configuration saved in ./results/tmp-checkpoint-65000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-65000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-65500
# Configuration saved in ./results/tmp-checkpoint-65500/config.json
# Configuration saved in ./results/tmp-checkpoint-65500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-65500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-66000
# Configuration saved in ./results/tmp-checkpoint-66000/config.json
# Configuration saved in ./results/tmp-checkpoint-66000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-66000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-66500
# Configuration saved in ./results/tmp-checkpoint-66500/config.json
# Configuration saved in ./results/tmp-checkpoint-66500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-66500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-67000
# Configuration saved in ./results/tmp-checkpoint-67000/config.json
# Configuration saved in ./results/tmp-checkpoint-67000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-67000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-67500
# Configuration saved in ./results/tmp-checkpoint-67500/config.json
# Configuration saved in ./results/tmp-checkpoint-67500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-67500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-68000
# Configuration saved in ./results/tmp-checkpoint-68000/config.json
# Configuration saved in ./results/tmp-checkpoint-68000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-68000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-68500
# Configuration saved in ./results/tmp-checkpoint-68500/config.json
# Configuration saved in ./results/tmp-checkpoint-68500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-68500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-69000
# Configuration saved in ./results/tmp-checkpoint-69000/config.json
# Configuration saved in ./results/tmp-checkpoint-69000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-69000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-69500
# Configuration saved in ./results/tmp-checkpoint-69500/config.json
# Configuration saved in ./results/tmp-checkpoint-69500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-69500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-70000
# Configuration saved in ./results/tmp-checkpoint-70000/config.json
# Configuration saved in ./results/tmp-checkpoint-70000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-70000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-70500
# Configuration saved in ./results/tmp-checkpoint-70500/config.json
# Configuration saved in ./results/tmp-checkpoint-70500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-70500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-71000
# Configuration saved in ./results/tmp-checkpoint-71000/config.json
# Configuration saved in ./results/tmp-checkpoint-71000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-71000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-71500
# Configuration saved in ./results/tmp-checkpoint-71500/config.json
# Configuration saved in ./results/tmp-checkpoint-71500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-71500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-72000
# Configuration saved in ./results/tmp-checkpoint-72000/config.json
# Configuration saved in ./results/tmp-checkpoint-72000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-72000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-72500
# Configuration saved in ./results/tmp-checkpoint-72500/config.json
# Configuration saved in ./results/tmp-checkpoint-72500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-72500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-73000
# Configuration saved in ./results/tmp-checkpoint-73000/config.json
# Configuration saved in ./results/tmp-checkpoint-73000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-73000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-73500
# Configuration saved in ./results/tmp-checkpoint-73500/config.json
# Configuration saved in ./results/tmp-checkpoint-73500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-73500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-74000
# Configuration saved in ./results/tmp-checkpoint-74000/config.json
# Configuration saved in ./results/tmp-checkpoint-74000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-74000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-74500
# Configuration saved in ./results/tmp-checkpoint-74500/config.json
# Configuration saved in ./results/tmp-checkpoint-74500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-74500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-75000
# Configuration saved in ./results/tmp-checkpoint-75000/config.json
# Configuration saved in ./results/tmp-checkpoint-75000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-75000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-75500
# Configuration saved in ./results/tmp-checkpoint-75500/config.json
# Configuration saved in ./results/tmp-checkpoint-75500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-75500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-76000
# Configuration saved in ./results/tmp-checkpoint-76000/config.json
# Configuration saved in ./results/tmp-checkpoint-76000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-76000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-76500
# Configuration saved in ./results/tmp-checkpoint-76500/config.json
# Configuration saved in ./results/tmp-checkpoint-76500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-76500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-77000
# Configuration saved in ./results/tmp-checkpoint-77000/config.json
# Configuration saved in ./results/tmp-checkpoint-77000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-77000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-77500
# Configuration saved in ./results/tmp-checkpoint-77500/config.json
# Configuration saved in ./results/tmp-checkpoint-77500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-77500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-78000
# Configuration saved in ./results/tmp-checkpoint-78000/config.json
# Configuration saved in ./results/tmp-checkpoint-78000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-78000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-78500
# Configuration saved in ./results/tmp-checkpoint-78500/config.json
# Configuration saved in ./results/tmp-checkpoint-78500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-78500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-79000
# Configuration saved in ./results/tmp-checkpoint-79000/config.json
# Configuration saved in ./results/tmp-checkpoint-79000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-79000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-79500
# Configuration saved in ./results/tmp-checkpoint-79500/config.json
# Configuration saved in ./results/tmp-checkpoint-79500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-79500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-80000
# Configuration saved in ./results/tmp-checkpoint-80000/config.json
# Configuration saved in ./results/tmp-checkpoint-80000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-80000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-80500
# Configuration saved in ./results/tmp-checkpoint-80500/config.json
# Configuration saved in ./results/tmp-checkpoint-80500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-80500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-81000
# Configuration saved in ./results/tmp-checkpoint-81000/config.json
# Configuration saved in ./results/tmp-checkpoint-81000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-81000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-81500
# Configuration saved in ./results/tmp-checkpoint-81500/config.json
# Configuration saved in ./results/tmp-checkpoint-81500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-81500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-82000
# Configuration saved in ./results/tmp-checkpoint-82000/config.json
# Configuration saved in ./results/tmp-checkpoint-82000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-82000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-82500
# Configuration saved in ./results/tmp-checkpoint-82500/config.json
# Configuration saved in ./results/tmp-checkpoint-82500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-82500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-83000
# Configuration saved in ./results/tmp-checkpoint-83000/config.json
# Configuration saved in ./results/tmp-checkpoint-83000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-83000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-83500
# Configuration saved in ./results/tmp-checkpoint-83500/config.json
# Configuration saved in ./results/tmp-checkpoint-83500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-83500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-84000
# Configuration saved in ./results/tmp-checkpoint-84000/config.json
# Configuration saved in ./results/tmp-checkpoint-84000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-84000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-84500
# Configuration saved in ./results/tmp-checkpoint-84500/config.json
# Configuration saved in ./results/tmp-checkpoint-84500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-84500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-85000
# Configuration saved in ./results/tmp-checkpoint-85000/config.json
# Configuration saved in ./results/tmp-checkpoint-85000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-85000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-85500
# Configuration saved in ./results/tmp-checkpoint-85500/config.json
# Configuration saved in ./results/tmp-checkpoint-85500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-85500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-86000
# Configuration saved in ./results/tmp-checkpoint-86000/config.json
# Configuration saved in ./results/tmp-checkpoint-86000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-86000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-86500
# Configuration saved in ./results/tmp-checkpoint-86500/config.json
# Configuration saved in ./results/tmp-checkpoint-86500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-86500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-87000
# Configuration saved in ./results/tmp-checkpoint-87000/config.json
# Configuration saved in ./results/tmp-checkpoint-87000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-87000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-87500
# Configuration saved in ./results/tmp-checkpoint-87500/config.json
# Configuration saved in ./results/tmp-checkpoint-87500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-87500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-88000
# Configuration saved in ./results/tmp-checkpoint-88000/config.json
# Configuration saved in ./results/tmp-checkpoint-88000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-88000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-88500
# Configuration saved in ./results/tmp-checkpoint-88500/config.json
# Configuration saved in ./results/tmp-checkpoint-88500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-88500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-89000
# Configuration saved in ./results/tmp-checkpoint-89000/config.json
# Configuration saved in ./results/tmp-checkpoint-89000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-89000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-89500
# Configuration saved in ./results/tmp-checkpoint-89500/config.json
# Configuration saved in ./results/tmp-checkpoint-89500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-89500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-90000
# Configuration saved in ./results/tmp-checkpoint-90000/config.json
# Configuration saved in ./results/tmp-checkpoint-90000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-90000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-90500
# Configuration saved in ./results/tmp-checkpoint-90500/config.json
# Configuration saved in ./results/tmp-checkpoint-90500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-90500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-91000
# Configuration saved in ./results/tmp-checkpoint-91000/config.json
# Configuration saved in ./results/tmp-checkpoint-91000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-91000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-91500
# Configuration saved in ./results/tmp-checkpoint-91500/config.json
# Configuration saved in ./results/tmp-checkpoint-91500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-91500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-92000
# Configuration saved in ./results/tmp-checkpoint-92000/config.json
# Configuration saved in ./results/tmp-checkpoint-92000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-92000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-92500
# Configuration saved in ./results/tmp-checkpoint-92500/config.json
# Configuration saved in ./results/tmp-checkpoint-92500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-92500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-93000
# Configuration saved in ./results/tmp-checkpoint-93000/config.json
# Configuration saved in ./results/tmp-checkpoint-93000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-93000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-93500
# Configuration saved in ./results/tmp-checkpoint-93500/config.json
# Configuration saved in ./results/tmp-checkpoint-93500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-93500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-94000
# Configuration saved in ./results/tmp-checkpoint-94000/config.json
# Configuration saved in ./results/tmp-checkpoint-94000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-94000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-94500
# Configuration saved in ./results/tmp-checkpoint-94500/config.json
# Configuration saved in ./results/tmp-checkpoint-94500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-94500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-95000
# Configuration saved in ./results/tmp-checkpoint-95000/config.json
# Configuration saved in ./results/tmp-checkpoint-95000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-95000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-95500
# Configuration saved in ./results/tmp-checkpoint-95500/config.json
# Configuration saved in ./results/tmp-checkpoint-95500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-95500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-96000
# Configuration saved in ./results/tmp-checkpoint-96000/config.json
# Configuration saved in ./results/tmp-checkpoint-96000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-96000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-96500
# Configuration saved in ./results/tmp-checkpoint-96500/config.json
# Configuration saved in ./results/tmp-checkpoint-96500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-96500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-97000
# Configuration saved in ./results/tmp-checkpoint-97000/config.json
# Configuration saved in ./results/tmp-checkpoint-97000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-97000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-97500
# Configuration saved in ./results/tmp-checkpoint-97500/config.json
# Configuration saved in ./results/tmp-checkpoint-97500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-97500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-98000
# Configuration saved in ./results/tmp-checkpoint-98000/config.json
# Configuration saved in ./results/tmp-checkpoint-98000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-98000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-98500
# Configuration saved in ./results/tmp-checkpoint-98500/config.json
# Configuration saved in ./results/tmp-checkpoint-98500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-98500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-99000
# Configuration saved in ./results/tmp-checkpoint-99000/config.json
# Configuration saved in ./results/tmp-checkpoint-99000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-99000/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-99500
# Configuration saved in ./results/tmp-checkpoint-99500/config.json
# Configuration saved in ./results/tmp-checkpoint-99500/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-99500/model.safetensors
# <ipython-input-14-0bf350ef82d0>:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Saving model checkpoint to ./results/tmp-checkpoint-100000
# Configuration saved in ./results/tmp-checkpoint-100000/config.json
# Configuration saved in ./results/tmp-checkpoint-100000/generation_config.json
# Model weights saved in ./results/tmp-checkpoint-100000/model.safetensors
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Configuration saved in model_dir/config.json
# Configuration saved in model_dir/generation_config.json
# Model weights saved in model_dir/model.safetensors
# tokenizer config file saved in model_dir/tokenizer_config.json
# Special tokens file saved in model_dir/special_tokens_map.json
# ('model_dir/tokenizer_config.json',
#  'model_dir/special_tokens_map.json',
#  'model_dir/vocab.json',
#  'model_dir/merges.txt',
#  'model_dir/added_tokens.json')
